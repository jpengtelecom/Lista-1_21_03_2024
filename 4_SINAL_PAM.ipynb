# %% [markdown]
# <a href="https://colab.research.google.com/github/jpengtelecom/Lista-1_21_03_2024/blob/main/4_SINAL_PAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matlab
# !pip install numpy
# !pip install matplotlib
# !pip install scipy
# !pip install random
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for matlab: filename=matlab-0.1-py3-none-any.whl size=1156 sha256=6560409baa7fed2b885d49463cd47650b4bc2f7e746d042db74e8c08a35940a9
#   Stored in directory: /root/.cache/pip/wheels/d1/d3/76/5314058ee22e7957a18eec0291788462f1df178bb08223bdd2
# Successfully built matlab
# ...
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
from scipy.special import erfc
from scipy import special
from scipy.fft import fft, fftfreq, ifft
from scipy.io import wavfile
from scipy.io.wavfile import write
from scipy.signal import welch
from scipy import signal

# Parametros
f = 10  #frequencia da portadora
f_m = 1   #frequencia do sinal mensagem
N = 2000  # amostragem
p = 30
t = np.linspace(-p,p,N,endpoint=False)


A= 1 #amplitude do sinal

# Portadora
data=(np.random.rand(10)>0.5)
data=(np.random.rand(10)>0.5)
portadora =0.5* np.repeat(data,200)



sinal_mensagem = A*np.sin(2*np.pi*f_m*t)


pam = sinal_mensagem*portadora #sinal PAM

pam_demo = sinal_mensagem*portadora  # sinal demodulado

# Filtro passa baixa
ordem = 700
frequencia_corte = 2
coeficientes = signal.firwin(ordem, frequencia_corte, fs=N)

# Demodulação do sinal usando filtro
sinal_original = np.convolve(coeficientes, pam_demo, mode='same')



# Plotar
plt.figure(1)
plt.plot(t, portadora)
plt.title('Portadora')
plt.xlabel('Tempo(s)')
plt.ylabel('Amplitude')
plt.grid()
plt.figure(2)
plt.plot(t, sinal_mensagem)
plt.title('Sinal Senoidal "Mensagem"')
plt.xlabel('Tempo(s)')
plt.ylabel('Amplitude')
plt.grid()
plt.figure(3)
plt.plot(t, pam)
plt.title('Pulse Amplitude Modulation')
plt.xlabel('Tempo(s)')
plt.ylabel('Amplitude')
plt.grid()
plt.figure(4)
plt.plot(t, pam_demo)
plt.title('PAM Demodulado')
plt.xlabel('Tempo(s)')
plt.ylabel('Amplitude')
plt.grid()
plt.figure(5)
plt.plot(t, sinal_original)
plt.title('Sinal Original "Filtrado"')
plt.xlabel('Tempo(s)')
plt.ylabel('Amplitude')
plt.grid()

plt.tight_layout()
plt.show()
